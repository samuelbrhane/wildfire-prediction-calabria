# %%
# Imports
import os
import pandas as pd

# %%
# Load and merge all yearly CSVs into one DataFrame
data_folder = "../1_data/processed/yearly"
csv_files = [f for f in os.listdir(data_folder) if f.endswith(".csv")]

all_data = []
for file in csv_files:
    df = pd.read_csv(os.path.join(data_folder, file))
    df["Date"] = pd.to_datetime(df["Date"], format="%Y%m%d")
    all_data.append(df)

climate_fire_df = pd.concat(all_data, ignore_index=True)
climate_fire_df.sort_values(["Zone_ID", "Date"], inplace=True)
climate_fire_df
# Out:
#        Zone_ID  Precipitation   Humidity  Temperature       Wind  Num_Fires  \
# 10608      1.0      22.339806  65.805280     7.730907   9.539081          0
# 10616      1.0      16.978067  75.892670     9.927811   8.074983          0
# 10624      1.0       5.139589  63.032867    12.678871   9.121183          0
# 10632      1.0      13.420406  87.038730     8.766089   5.736721          0
# 10640      1.0       3.897444  48.778150    16.070381   7.448781          0
# ...        ...            ...        ...          ...        ...        ...
# 7039       8.0       0.006360  52.858080    21.086908  24.872744          0
# 7047       8.0      44.580208  81.528370    19.032253  27.734533          0
# 7055       8.0      32.856617  81.494095    18.900959  26.939358          0
# 7063       8.0       6.381305  67.720200    17.669884  13.743039          0
# 7071       8.0       0.008643  48.280888    15.742384  12.702726          0
#
#             Date
# 10608 2008-03-25
# 10616 2008-03-26
# 10624 2008-03-27
# 10632 2008-03-28
# 10640 2008-03-29
# ...          ...
# 7039  2018-10-27
# 7047  2018-10-28
# 7055  2018-10-29
# 7063  2018-10-30
# 7071  2018-10-31
#
# [19448 rows x 7 columns]

# %%
# Clean and save merged dataset
climate_fire_df["Zone_ID"] = climate_fire_df["Zone_ID"].astype(int)
climate_fire_df.reset_index(drop=True, inplace=True)

columns = ["Date"] + [col for col in climate_fire_df.columns if col != "Date"]
climate_fire_df = climate_fire_df[columns]

climate_fire_df.to_csv("../1_data/processed/zone_sequence_merged.csv", index=False)
print(f"Merged dataset saved: {climate_fire_df.shape[0]} rows, {climate_fire_df.shape[1]} columns")
climate_fire_df
# Out:
# Merged dataset saved: 19448 rows, 7 columns
#             Date  Zone_ID  Precipitation   Humidity  Temperature       Wind  \
# 0     2008-03-25        1      22.339806  65.805280     7.730907   9.539081
# 1     2008-03-26        1      16.978067  75.892670     9.927811   8.074983
# 2     2008-03-27        1       5.139589  63.032867    12.678871   9.121183
# 3     2008-03-28        1      13.420406  87.038730     8.766089   5.736721
# 4     2008-03-29        1       3.897444  48.778150    16.070381   7.448781
# ...          ...      ...            ...        ...          ...        ...
# 19443 2018-10-27        8       0.006360  52.858080    21.086908  24.872744
# 19444 2018-10-28        8      44.580208  81.528370    19.032253  27.734533
# 19445 2018-10-29        8      32.856617  81.494095    18.900959  26.939358
# 19446 2018-10-30        8       6.381305  67.720200    17.669884  13.743039
# 19447 2018-10-31        8       0.008643  48.280888    15.742384  12.702726
#
#        Num_Fires
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 19443          0
# 19444          0
# 19445          0
# 19446          0
# 19447          0
#
# [19448 rows x 7 columns]

# %%
# Check for missing values
missing = climate_fire_df.isnull().sum()
print(missing)
# Out:
# Date             0
# Zone_ID          0
# Precipitation    0
# Humidity         0
# Temperature      0
# Wind             0
# Num_Fires        0
# dtype: int64
